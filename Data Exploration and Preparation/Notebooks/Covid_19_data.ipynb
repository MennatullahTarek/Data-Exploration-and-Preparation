# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500"> Covid-19 data for Italy 🤒 </p>

# %% [markdown]
# <img src="https://media0.giphy.com/media/MCAFTO4btHOaiNRO1k/200.webp?cid=790b7611yriwbe5vspsallv6twjyu6kae74xm13jpe5y5l9u&ep=v1_gifs_search&rid=200.webp&ct=g" width="150%" height="100%">

# %% [markdown]
# <a id="dataoverview"></a>
# # <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500"> Import the Necessary Libraries 📚</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# <a id="datareading"></a>
# # <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500"> Reading the data 📖</p>

# %%
data = pd.read_csv('/content/italy-covid-daywise.csv')
data.tail().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ca27e_row0_col1, #T_ca27e_row2_col3, #T_ca27e_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ca27e_row0_col2, #T_ca27e_row1_col3, #T_ca27e_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ca27e_row0_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_ca27e_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_ca27e_row1_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_ca27e_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ca27e_row2_col2, #T_ca27e_row4_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_ca27e_row3_col3, #T_ca27e_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ca27e_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ca27e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca27e_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_ca27e_level0_col1" class="col_heading level0 col1" >new_cases</th>
#       <th id="T_ca27e_level0_col2" class="col_heading level0 col2" >new_deaths</th>
#       <th id="T_ca27e_level0_col3" class="col_heading level0 col3" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca27e_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_ca27e_row0_col0" class="data row0 col0" >2020-08-30</td>
#       <td id="T_ca27e_row0_col1" class="data row0 col1" >1444.000000</td>
#       <td id="T_ca27e_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_ca27e_row0_col3" class="data row0 col3" >53541.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ca27e_level0_row1" class="row_heading level0 row1" >244</th>
#       <td id="T_ca27e_row1_col0" class="data row1 col0" >2020-08-31</td>
#       <td id="T_ca27e_row1_col1" class="data row1 col1" >1365.000000</td>
#       <td id="T_ca27e_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_ca27e_row1_col3" class="data row1 col3" >42583.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ca27e_level0_row2" class="row_heading level0 row2" >245</th>
#       <td id="T_ca27e_row2_col0" class="data row2 col0" >2020-09-01</td>
#       <td id="T_ca27e_row2_col1" class="data row2 col1" >996.000000</td>
#       <td id="T_ca27e_row2_col2" class="data row2 col2" >6.000000</td>
#       <td id="T_ca27e_row2_col3" class="data row2 col3" >54395.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ca27e_level0_row3" class="row_heading level0 row3" >246</th>
#       <td id="T_ca27e_row3_col0" class="data row3 col0" >2020-09-02</td>
#       <td id="T_ca27e_row3_col1" class="data row3 col1" >975.000000</td>
#       <td id="T_ca27e_row3_col2" class="data row3 col2" >8.000000</td>
#       <td id="T_ca27e_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ca27e_level0_row4" class="row_heading level0 row4" >247</th>
#       <td id="T_ca27e_row4_col0" class="data row4 col0" >2020-09-03</td>
#       <td id="T_ca27e_row4_col1" class="data row4 col1" >1326.000000</td>
#       <td id="T_ca27e_row4_col2" class="data row4 col2" >6.000000</td>
#       <td id="T_ca27e_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
#retrieve the number of rows and columns in the data frame
data.shape
# Out:
# (248, 4)

# %%
#view statistical information for numerical columns
data.describe().T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_982e1_row0_col0, #T_982e1_row1_col0, #T_982e1_row2_col1, #T_982e1_row2_col2, #T_982e1_row2_col3, #T_982e1_row2_col4, #T_982e1_row2_col5, #T_982e1_row2_col6, #T_982e1_row2_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_982e1_row0_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_982e1_row0_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_982e1_row0_col3, #T_982e1_row1_col1, #T_982e1_row1_col2, #T_982e1_row1_col4, #T_982e1_row1_col5, #T_982e1_row1_col6, #T_982e1_row1_col7, #T_982e1_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_982e1_row0_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_982e1_row0_col5 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_982e1_row0_col6 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_982e1_row0_col7 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_982e1_row1_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_982e1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_982e1_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_982e1_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_982e1_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_982e1_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_982e1_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_982e1_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_982e1_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_982e1_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_982e1_level0_row0" class="row_heading level0 row0" >new_cases</th>
#       <td id="T_982e1_row0_col0" class="data row0 col0" >248.000000</td>
#       <td id="T_982e1_row0_col1" class="data row0 col1" >1094.818548</td>
#       <td id="T_982e1_row0_col2" class="data row0 col2" >1554.508002</td>
#       <td id="T_982e1_row0_col3" class="data row0 col3" >-148.000000</td>
#       <td id="T_982e1_row0_col4" class="data row0 col4" >123.000000</td>
#       <td id="T_982e1_row0_col5" class="data row0 col5" >342.000000</td>
#       <td id="T_982e1_row0_col6" class="data row0 col6" >1371.750000</td>
#       <td id="T_982e1_row0_col7" class="data row0 col7" >6557.000000</td>
#     </tr>
#     <tr>
#       <th id="T_982e1_level0_row1" class="row_heading level0 row1" >new_deaths</th>
#       <td id="T_982e1_row1_col0" class="data row1 col0" >248.000000</td>
#       <td id="T_982e1_row1_col1" class="data row1 col1" >143.133065</td>
#       <td id="T_982e1_row1_col2" class="data row1 col2" >227.105538</td>
#       <td id="T_982e1_row1_col3" class="data row1 col3" >-31.000000</td>
#       <td id="T_982e1_row1_col4" class="data row1 col4" >3.000000</td>
#       <td id="T_982e1_row1_col5" class="data row1 col5" >17.000000</td>
#       <td id="T_982e1_row1_col6" class="data row1 col6" >175.250000</td>
#       <td id="T_982e1_row1_col7" class="data row1 col7" >971.000000</td>
#     </tr>
#     <tr>
#       <th id="T_982e1_level0_row2" class="row_heading level0 row2" >new_tests</th>
#       <td id="T_982e1_row2_col0" class="data row2 col0" >135.000000</td>
#       <td id="T_982e1_row2_col1" class="data row2 col1" >31699.674074</td>
#       <td id="T_982e1_row2_col2" class="data row2 col2" >11622.209757</td>
#       <td id="T_982e1_row2_col3" class="data row2 col3" >7841.000000</td>
#       <td id="T_982e1_row2_col4" class="data row2 col4" >25259.000000</td>
#       <td id="T_982e1_row2_col5" class="data row2 col5" >29545.000000</td>
#       <td id="T_982e1_row2_col6" class="data row2 col6" >37711.000000</td>
#       <td id="T_982e1_row2_col7" class="data row2 col7" >95273.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.describe(include="object").T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef669" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef669_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_ef669_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_ef669_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_ef669_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef669_level0_row0" class="row_heading level0 row0" >date</th>
#       <td id="T_ef669_row0_col0" class="data row0 col0" >248</td>
#       <td id="T_ef669_row0_col1" class="data row0 col1" >248</td>
#       <td id="T_ef669_row0_col2" class="data row0 col2" >2019-12-31</td>
#       <td id="T_ef669_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
#view some basic information about the data frame like data types, and number of non-nulls
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
data.dtypes
# Out:
# date           object
# new_cases     float64
# new_deaths    float64
# new_tests     float64
# dtype: object

# %%
data.isna().sum()
# Out:
# date            0
# new_cases       0
# new_deaths      0
# new_tests     113
# dtype: int64

# %%
data.isna().sum()/data.shape[0]*100
# Out:
# date           0.000000
# new_cases      0.000000
# new_deaths     0.000000
# new_tests     45.564516
# dtype: float64

# %%
data.nunique()
# Out:
# date          248
# new_cases     188
# new_deaths    129
# new_tests     135
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[(data.iloc[:, 1] == 0) & (data.iloc[:, 2] == 0)].style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_61792_row0_col1, #T_61792_row0_col2, #T_61792_row1_col1, #T_61792_row1_col2, #T_61792_row2_col1, #T_61792_row2_col2, #T_61792_row3_col1, #T_61792_row3_col2, #T_61792_row4_col1, #T_61792_row4_col2, #T_61792_row5_col1, #T_61792_row5_col2, #T_61792_row6_col1, #T_61792_row6_col2, #T_61792_row7_col1, #T_61792_row7_col2, #T_61792_row8_col1, #T_61792_row8_col2, #T_61792_row9_col1, #T_61792_row9_col2, #T_61792_row10_col1, #T_61792_row10_col2, #T_61792_row11_col1, #T_61792_row11_col2, #T_61792_row12_col1, #T_61792_row12_col2, #T_61792_row13_col1, #T_61792_row13_col2, #T_61792_row14_col1, #T_61792_row14_col2, #T_61792_row15_col1, #T_61792_row15_col2, #T_61792_row16_col1, #T_61792_row16_col2, #T_61792_row17_col1, #T_61792_row17_col2, #T_61792_row18_col1, #T_61792_row18_col2, #T_61792_row19_col1, #T_61792_row19_col2, #T_61792_row20_col1, #T_61792_row20_col2, #T_61792_row21_col1, #T_61792_row21_col2, #T_61792_row22_col1, #T_61792_row22_col2, #T_61792_row23_col1, #T_61792_row23_col2, #T_61792_row24_col1, #T_61792_row24_col2, #T_61792_row25_col1, #T_61792_row25_col2, #T_61792_row26_col1, #T_61792_row26_col2, #T_61792_row27_col1, #T_61792_row27_col2, #T_61792_row28_col1, #T_61792_row28_col2, #T_61792_row29_col1, #T_61792_row29_col2, #T_61792_row30_col1, #T_61792_row30_col2, #T_61792_row31_col1, #T_61792_row31_col2, #T_61792_row32_col1, #T_61792_row32_col2, #T_61792_row33_col1, #T_61792_row33_col2, #T_61792_row34_col1, #T_61792_row34_col2, #T_61792_row35_col1, #T_61792_row35_col2, #T_61792_row36_col1, #T_61792_row36_col2, #T_61792_row37_col1, #T_61792_row37_col2, #T_61792_row38_col1, #T_61792_row38_col2, #T_61792_row39_col1, #T_61792_row39_col2, #T_61792_row40_col1, #T_61792_row40_col2, #T_61792_row41_col1, #T_61792_row41_col2, #T_61792_row42_col1, #T_61792_row42_col2, #T_61792_row43_col1, #T_61792_row43_col2, #T_61792_row44_col1, #T_61792_row44_col2, #T_61792_row45_col1, #T_61792_row45_col2, #T_61792_row46_col1, #T_61792_row46_col2, #T_61792_row47_col1, #T_61792_row47_col2, #T_61792_row48_col1, #T_61792_row48_col2, #T_61792_row49_col1, #T_61792_row49_col2, #T_61792_row50_col1, #T_61792_row50_col2, #T_61792_row51_col1, #T_61792_row51_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_61792_row0_col3, #T_61792_row1_col3, #T_61792_row2_col3, #T_61792_row3_col3, #T_61792_row4_col3, #T_61792_row5_col3, #T_61792_row6_col3, #T_61792_row7_col3, #T_61792_row8_col3, #T_61792_row9_col3, #T_61792_row10_col3, #T_61792_row11_col3, #T_61792_row12_col3, #T_61792_row13_col3, #T_61792_row14_col3, #T_61792_row15_col3, #T_61792_row16_col3, #T_61792_row17_col3, #T_61792_row18_col3, #T_61792_row19_col3, #T_61792_row20_col3, #T_61792_row21_col3, #T_61792_row22_col3, #T_61792_row23_col3, #T_61792_row24_col3, #T_61792_row25_col3, #T_61792_row26_col3, #T_61792_row27_col3, #T_61792_row28_col3, #T_61792_row29_col3, #T_61792_row30_col3, #T_61792_row31_col3, #T_61792_row32_col3, #T_61792_row33_col3, #T_61792_row34_col3, #T_61792_row35_col3, #T_61792_row36_col3, #T_61792_row37_col3, #T_61792_row38_col3, #T_61792_row39_col3, #T_61792_row40_col3, #T_61792_row41_col3, #T_61792_row42_col3, #T_61792_row43_col3, #T_61792_row44_col3, #T_61792_row45_col3, #T_61792_row46_col3, #T_61792_row47_col3, #T_61792_row48_col3, #T_61792_row49_col3, #T_61792_row50_col3, #T_61792_row51_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_61792" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61792_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_61792_level0_col1" class="col_heading level0 col1" >new_cases</th>
#       <th id="T_61792_level0_col2" class="col_heading level0 col2" >new_deaths</th>
#       <th id="T_61792_level0_col3" class="col_heading level0 col3" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61792_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61792_row0_col0" class="data row0 col0" >2019-12-31</td>
#       <td id="T_61792_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_61792_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_61792_row0_col3" class="data row0 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61792_row1_col0" class="data row1 col0" >2020-01-01</td>
#       <td id="T_61792_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_61792_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_61792_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61792_row2_col0" class="data row2 col0" >2020-01-02</td>
#       <td id="T_61792_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_61792_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_61792_row2_col3" class="data row2 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_61792_row3_col0" class="data row3 col0" >2020-01-03</td>
#       <td id="T_61792_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_61792_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_61792_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_61792_row4_col0" class="data row4 col0" >2020-01-04</td>
#       <td id="T_61792_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_61792_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_61792_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_61792_row5_col0" class="data row5 col0" >2020-01-05</td>
#       <td id="T_61792_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_61792_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_61792_row5_col3" class="data row5 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_61792_row6_col0" class="data row6 col0" >2020-01-06</td>
#       <td id="T_61792_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_61792_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_61792_row6_col3" class="data row6 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_61792_row7_col0" class="data row7 col0" >2020-01-07</td>
#       <td id="T_61792_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_61792_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_61792_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_61792_row8_col0" class="data row8 col0" >2020-01-08</td>
#       <td id="T_61792_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_61792_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_61792_row8_col3" class="data row8 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_61792_row9_col0" class="data row9 col0" >2020-01-09</td>
#       <td id="T_61792_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_61792_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_61792_row9_col3" class="data row9 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61792_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_61792_row10_col0" class="data row10 col0" >2020-01-10</td>
#       <td id="T_61792_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_61792_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_61792_row10_col3" class="data row10 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T

# %% [markdown]
# ## Initial Data Assessment 📋
# - **Number of Samples**: `240`
# - **Number of Columns**: `4`
# - **Missing Values**:`113` Missing values in the "new_tests" column, about `45%` of data.
# - **Data Types**:
#   - Object (Categorical): 1 column >> `date`.
#   - And the other `3` columns float
#
# - **Data Distribution**:
#   - date is categorical (should be datetime).
#   - Numeric features have varying ranges and distributions.
#
#   - There are no duplicate rows in either DataFrame
#
#   - **Note**:
#   - There are zero `new_cases`,	`new_deaths` or	`new_tests` until `2020-02-21`

# %%
#create a list of columns within the data frame
columns_list = data.columns.tolist()

# %%
#return only the days which had more than 1000 reported cases
data[data['new_cases'] > 1000].style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a63c2_row0_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_a63c2_row0_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_a63c2_row0_col3, #T_a63c2_row1_col3, #T_a63c2_row2_col3, #T_a63c2_row3_col3, #T_a63c2_row4_col3, #T_a63c2_row5_col3, #T_a63c2_row6_col3, #T_a63c2_row7_col3, #T_a63c2_row8_col3, #T_a63c2_row9_col3, #T_a63c2_row10_col3, #T_a63c2_row11_col3, #T_a63c2_row12_col3, #T_a63c2_row13_col3, #T_a63c2_row14_col3, #T_a63c2_row15_col3, #T_a63c2_row16_col3, #T_a63c2_row17_col3, #T_a63c2_row18_col3, #T_a63c2_row19_col3, #T_a63c2_row20_col3, #T_a63c2_row21_col3, #T_a63c2_row22_col3, #T_a63c2_row23_col3, #T_a63c2_row24_col3, #T_a63c2_row25_col3, #T_a63c2_row26_col3, #T_a63c2_row27_col3, #T_a63c2_row28_col3, #T_a63c2_row29_col3, #T_a63c2_row30_col3, #T_a63c2_row31_col3, #T_a63c2_row32_col3, #T_a63c2_row33_col3, #T_a63c2_row34_col3, #T_a63c2_row35_col3, #T_a63c2_row36_col3, #T_a63c2_row37_col3, #T_a63c2_row38_col3, #T_a63c2_row39_col3, #T_a63c2_row40_col3, #T_a63c2_row41_col3, #T_a63c2_row71_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a63c2_row1_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_a63c2_row1_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_a63c2_row2_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_a63c2_row2_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_a63c2_row3_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_a63c2_row3_col2, #T_a63c2_row57_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_a63c2_row4_col1, #T_a63c2_row46_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_a63c2_row4_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_a63c2_row5_col1, #T_a63c2_row49_col2, #T_a63c2_row54_col3, #T_a63c2_row62_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_a63c2_row5_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_a63c2_row6_col1, #T_a63c2_row35_col2, #T_a63c2_row40_col1 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_a63c2_row6_col2, #T_a63c2_row56_col2, #T_a63c2_row63_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_a63c2_row7_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_a63c2_row7_col2, #T_a63c2_row36_col1, #T_a63c2_row59_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_a63c2_row8_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_a63c2_row8_col2, #T_a63c2_row9_col2, #T_a63c2_row30_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_a63c2_row9_col1, #T_a63c2_row42_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_a63c2_row10_col1, #T_a63c2_row32_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_a63c2_row10_col2, #T_a63c2_row55_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_a63c2_row11_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_a63c2_row11_col2, #T_a63c2_row41_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_a63c2_row12_col1 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_a63c2_row12_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_a63c2_row13_col1, #T_a63c2_row19_col2, #T_a63c2_row46_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a63c2_row13_col2, #T_a63c2_row14_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_a63c2_row14_col2 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_a63c2_row15_col1, #T_a63c2_row18_col2, #T_a63c2_row24_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_a63c2_row15_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_a63c2_row16_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_a63c2_row16_col2 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_a63c2_row17_col1, #T_a63c2_row21_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_a63c2_row17_col2 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_a63c2_row18_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_a63c2_row19_col1, #T_a63c2_row20_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_a63c2_row20_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_a63c2_row21_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_a63c2_row22_col1, #T_a63c2_row23_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_a63c2_row22_col2 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_a63c2_row23_col2 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_a63c2_row24_col2 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_a63c2_row25_col1, #T_a63c2_row29_col2, #T_a63c2_row67_col3 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_a63c2_row25_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_a63c2_row26_col1, #T_a63c2_row34_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_a63c2_row26_col2 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_a63c2_row27_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_a63c2_row27_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_a63c2_row28_col1, #T_a63c2_row40_col2 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_a63c2_row28_col2, #T_a63c2_row39_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_a63c2_row29_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_a63c2_row30_col2, #T_a63c2_row37_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_a63c2_row31_col1 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_a63c2_row31_col2 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_a63c2_row32_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_a63c2_row33_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_a63c2_row33_col2 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_a63c2_row34_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_a63c2_row35_col1, #T_a63c2_row44_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_a63c2_row36_col2 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_a63c2_row37_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_a63c2_row38_col1, #T_a63c2_row53_col2, #T_a63c2_row65_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_a63c2_row38_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_a63c2_row39_col1, #T_a63c2_row41_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_a63c2_row42_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_a63c2_row42_col3, #T_a63c2_row58_col1, #T_a63c2_row62_col1, #T_a63c2_row64_col1, #T_a63c2_row64_col2, #T_a63c2_row69_col2, #T_a63c2_row70_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a63c2_row43_col1, #T_a63c2_row49_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_a63c2_row43_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_a63c2_row43_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_a63c2_row44_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_a63c2_row44_col3 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_a63c2_row45_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_a63c2_row45_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_a63c2_row45_col3, #T_a63c2_row63_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_a63c2_row46_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_a63c2_row47_col1, #T_a63c2_row47_col3, #T_a63c2_row51_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_a63c2_row47_col2, #T_a63c2_row60_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_a63c2_row48_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_a63c2_row48_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_a63c2_row48_col3, #T_a63c2_row51_col1, #T_a63c2_row52_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_a63c2_row49_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_a63c2_row50_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_a63c2_row50_col2, #T_a63c2_row58_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_a63c2_row50_col3 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_a63c2_row51_col2 {
#   background-color: #97c6df;
#   color:

# %%
#create positive_rate column that is equal to new_cases / new_tests
data['positive_rate'] = data['new_cases'] / data['new_tests']
data.tail().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_6831e_row0_col1, #T_6831e_row1_col4, #T_6831e_row2_col3, #T_6831e_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6831e_row0_col2, #T_6831e_row1_col3, #T_6831e_row2_col4, #T_6831e_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6831e_row0_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_6831e_row0_col4 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_6831e_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_6831e_row1_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_6831e_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_6831e_row2_col2, #T_6831e_row4_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_6831e_row3_col3, #T_6831e_row3_col4, #T_6831e_row4_col3, #T_6831e_row4_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_6831e_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6831e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6831e_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_6831e_level0_col1" class="col_heading level0 col1" >new_cases</th>
#       <th id="T_6831e_level0_col2" class="col_heading level0 col2" >new_deaths</th>
#       <th id="T_6831e_level0_col3" class="col_heading level0 col3" >new_tests</th>
#       <th id="T_6831e_level0_col4" class="col_heading level0 col4" >positive_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6831e_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_6831e_row0_col0" class="data row0 col0" >2020-08-30</td>
#       <td id="T_6831e_row0_col1" class="data row0 col1" >1444.000000</td>
#       <td id="T_6831e_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_6831e_row0_col3" class="data row0 col3" >53541.000000</td>
#       <td id="T_6831e_row0_col4" class="data row0 col4" >0.026970</td>
#     </tr>
#     <tr>
#       <th id="T_6831e_level0_row1" class="row_heading level0 row1" >244</th>
#       <td id="T_6831e_row1_col0" class="data row1 col0" >2020-08-31</td>
#       <td id="T_6831e_row1_col1" class="data row1 col1" >1365.000000</td>
#       <td id="T_6831e_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_6831e_row1_col3" class="data row1 col3" >42583.000000</td>
#       <td id="T_6831e_row1_col4" class="data row1 col4" >0.032055</td>
#     </tr>
#     <tr>
#       <th id="T_6831e_level0_row2" class="row_heading level0 row2" >245</th>
#       <td id="T_6831e_row2_col0" class="data row2 col0" >2020-09-01</td>
#       <td id="T_6831e_row2_col1" class="data row2 col1" >996.000000</td>
#       <td id="T_6831e_row2_col2" class="data row2 col2" >6.000000</td>
#       <td id="T_6831e_row2_col3" class="data row2 col3" >54395.000000</td>
#       <td id="T_6831e_row2_col4" class="data row2 col4" >0.018311</td>
#     </tr>
#     <tr>
#       <th id="T_6831e_level0_row3" class="row_heading level0 row3" >246</th>
#       <td id="T_6831e_row3_col0" class="data row3 col0" >2020-09-02</td>
#       <td id="T_6831e_row3_col1" class="data row3 col1" >975.000000</td>
#       <td id="T_6831e_row3_col2" class="data row3 col2" >8.000000</td>
#       <td id="T_6831e_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_6831e_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6831e_level0_row4" class="row_heading level0 row4" >247</th>
#       <td id="T_6831e_row4_col0" class="data row4 col0" >2020-09-03</td>
#       <td id="T_6831e_row4_col1" class="data row4 col1" >1326.000000</td>
#       <td id="T_6831e_row4_col2" class="data row4 col2" >6.000000</td>
#       <td id="T_6831e_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_6831e_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
#let's remove the positive_rate column
data.drop(columns=['positive_rate'], inplace=True)
data.tail().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d00a0_row0_col1, #T_d00a0_row2_col3, #T_d00a0_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d00a0_row0_col2, #T_d00a0_row1_col3, #T_d00a0_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d00a0_row0_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_d00a0_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_d00a0_row1_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_d00a0_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d00a0_row2_col2, #T_d00a0_row4_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_d00a0_row3_col3, #T_d00a0_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d00a0_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d00a0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d00a0_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_d00a0_level0_col1" class="col_heading level0 col1" >new_cases</th>
#       <th id="T_d00a0_level0_col2" class="col_heading level0 col2" >new_deaths</th>
#       <th id="T_d00a0_level0_col3" class="col_heading level0 col3" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d00a0_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_d00a0_row0_col0" class="data row0 col0" >2020-08-30</td>
#       <td id="T_d00a0_row0_col1" class="data row0 col1" >1444.000000</td>
#       <td id="T_d00a0_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_d00a0_row0_col3" class="data row0 col3" >53541.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row1" class="row_heading level0 row1" >244</th>
#       <td id="T_d00a0_row1_col0" class="data row1 col0" >2020-08-31</td>
#       <td id="T_d00a0_row1_col1" class="data row1 col1" >1365.000000</td>
#       <td id="T_d00a0_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_d00a0_row1_col3" class="data row1 col3" >42583.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row2" class="row_heading level0 row2" >245</th>
#       <td id="T_d00a0_row2_col0" class="data row2 col0" >2020-09-01</td>
#       <td id="T_d00a0_row2_col1" class="data row2 col1" >996.000000</td>
#       <td id="T_d00a0_row2_col2" class="data row2 col2" >6.000000</td>
#       <td id="T_d00a0_row2_col3" class="data row2 col3" >54395.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row3" class="row_heading level0 row3" >246</th>
#       <td id="T_d00a0_row3_col0" class="data row3 col0" >2020-09-02</td>
#       <td id="T_d00a0_row3_col1" class="data row3 col1" >975.000000</td>
#       <td id="T_d00a0_row3_col2" class="data row3 col2" >8.000000</td>
#       <td id="T_d00a0_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d00a0_level0_row4" class="row_heading level0 row4" >247</th>
#       <td id="T_d00a0_row4_col0" class="data row4 col0" >2020-09-03</td>
#       <td id="T_d00a0_row4_col1" class="data row4 col1" >1326.000000</td>
#       <td id="T_d00a0_row4_col2" class="data row4 col2" >6.000000</td>
#       <td id="T_d00a0_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
#sort to identify the days with the highest number of cases
data.sort_values('new_cases', ascending=False).reset_index(drop=True).head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_104f7_row0_col1, #T_104f7_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_104f7_row0_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_104f7_row0_col3, #T_104f7_row1_col3, #T_104f7_row2_col3, #T_104f7_row3_col3, #T_104f7_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_104f7_row1_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_104f7_row1_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_104f7_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_104f7_row2_col2, #T_104f7_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_104f7_row3_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_104f7_row3_col2 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_104f7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_104f7_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_104f7_level0_col1" class="col_heading level0 col1" >new_cases</th>
#       <th id="T_104f7_level0_col2" class="col_heading level0 col2" >new_deaths</th>
#       <th id="T_104f7_level0_col3" class="col_heading level0 col3" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_104f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_104f7_row0_col0" class="data row0 col0" >2020-03-22</td>
#       <td id="T_104f7_row0_col1" class="data row0 col1" >6557.000000</td>
#       <td id="T_104f7_row0_col2" class="data row0 col2" >795.000000</td>
#       <td id="T_104f7_row0_col3" class="data row0 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_104f7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_104f7_row1_col0" class="data row1 col0" >2020-03-27</td>
#       <td id="T_104f7_row1_col1" class="data row1 col1" >6153.000000</td>
#       <td id="T_104f7_row1_col2" class="data row1 col2" >660.000000</td>
#       <td id="T_104f7_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_104f7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_104f7_row2_col0" class="data row2 col0" >2020-03-21</td>
#       <td id="T_104f7_row2_col1" class="data row2 col1" >5986.000000</td>
#       <td id="T_104f7_row2_col2" class="data row2 col2" >625.000000</td>
#       <td id="T_104f7_row2_col3" class="data row2 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_104f7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_104f7_row3_col0" class="data row3 col0" >2020-03-29</td>
#       <td id="T_104f7_row3_col1" class="data row3 col1" >5974.000000</td>
#       <td id="T_104f7_row3_col2" class="data row3 col2" >887.000000</td>
#       <td id="T_104f7_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_104f7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_104f7_row4_col0" class="data row4 col0" >2020-03-28</td>
#       <td id="T_104f7_row4_col1" class="data row4 col1" >5959.000000</td>
#       <td id="T_104f7_row4_col2" class="data row4 col2" >971.000000</td>
#       <td id="T_104f7_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### The dayes with heighest number of cases are:
# - `22-3-2020` with `6557 case`
# - `27-3-2020` with `6153 case`
# - `21-3-2020` with `5986 case`

# %%
#check the data type of date column,then convert it into a datetime
data.dtypes
# Out:
# date           object
# new_cases     float64
# new_deaths    float64
# new_tests     float64
# dtype: object

# %%
data['date'] = pd.to_datetime(data['date'], errors='coerce')
data.tail().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_72671_row0_col1, #T_72671_row2_col3, #T_72671_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_72671_row0_col2, #T_72671_row1_col3, #T_72671_row3_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_72671_row0_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_72671_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_72671_row1_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_72671_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_72671_row2_col2, #T_72671_row4_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_72671_row3_col3, #T_72671_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_72671_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72671" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72671_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_72671_level0_col1" class="col_heading level0 col1" >new_cases</th>
#       <th id="T_72671_level0_col2" class="col_heading level0 col2" >new_deaths</th>
#       <th id="T_72671_level0_col3" class="col_heading level0 col3" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72671_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_72671_row0_col0" class="data row0 col0" >2020-08-30 00:00:00</td>
#       <td id="T_72671_row0_col1" class="data row0 col1" >1444.000000</td>
#       <td id="T_72671_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_72671_row0_col3" class="data row0 col3" >53541.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72671_level0_row1" class="row_heading level0 row1" >244</th>
#       <td id="T_72671_row1_col0" class="data row1 col0" >2020-08-31 00:00:00</td>
#       <td id="T_72671_row1_col1" class="data row1 col1" >1365.000000</td>
#       <td id="T_72671_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_72671_row1_col3" class="data row1 col3" >42583.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72671_level0_row2" class="row_heading level0 row2" >245</th>
#       <td id="T_72671_row2_col0" class="data row2 col0" >2020-09-01 00:00:00</td>
#       <td id="T_72671_row2_col1" class="data row2 col1" >996.000000</td>
#       <td id="T_72671_row2_col2" class="data row2 col2" >6.000000</td>
#       <td id="T_72671_row2_col3" class="data row2 col3" >54395.000000</td>
#     </tr>
#     <tr>
#       <th id="T_72671_level0_row3" class="row_heading level0 row3" >246</th>
#       <td id="T_72671_row3_col0" class="data row3 col0" >2020-09-02 00:00:00</td>
#       <td id="T_72671_row3_col1" class="data row3 col1" >975.000000</td>
#       <td id="T_72671_row3_col2" class="data row3 col2" >8.000000</td>
#       <td id="T_72671_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_72671_level0_row4" class="row_heading level0 row4" >247</th>
#       <td id="T_72671_row4_col0" class="data row4 col0" >2020-09-03 00:00:00</td>
#       <td id="T_72671_row4_col1" class="data row4 col1" >1326.000000</td>
#       <td id="T_72671_row4_col2" class="data row4 col2" >6.000000</td>
#       <td id="T_72671_row4_col3" class="data row4 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.dtypes
# Out:
# date          datetime64[ns]
# new_cases            float64
# new_deaths           float64
# new_tests            float64
# dtype: object

# %%
#extract different parts(day, month, weekday, and year) of the date column into separate columns
data['day'] = data['date'].dt.day
data['month'] = data['date'].dt.month
data['weekday'] = data['date'].dt.weekday
data['year'] = data['date'].dt.year
data.tail().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_e8fd5_row0_col1, #T_e8fd5_row0_col6, #T_e8fd5_row1_col4, #T_e8fd5_row2_col3, #T_e8fd5_row2_col5, #T_e8fd5_row3_col2, #T_e8fd5_row3_col5, #T_e8fd5_row4_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e8fd5_row0_col2, #T_e8fd5_row0_col5, #T_e8fd5_row0_col7, #T_e8fd5_row1_col3, #T_e8fd5_row1_col5, #T_e8fd5_row1_col6, #T_e8fd5_row1_col7, #T_e8fd5_row2_col4, #T_e8fd5_row2_col7, #T_e8fd5_row3_col1, #T_e8fd5_row3_col7, #T_e8fd5_row4_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e8fd5_row0_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_e8fd5_row0_col4 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_e8fd5_row1_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_e8fd5_row1_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_e8fd5_row2_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_e8fd5_row2_col2, #T_e8fd5_row4_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_e8fd5_row2_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_e8fd5_row3_col3, #T_e8fd5_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e8fd5_row3_col4 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_e8fd5_row3_col6 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_e8fd5_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_e8fd5_row4_col4 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_e8fd5_row4_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e8fd5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8fd5_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_e8fd5_level0_col1" class="col_heading level0 col1" >new_cases</th>
#       <th id="T_e8fd5_level0_col2" class="col_heading level0 col2" >new_deaths</th>
#       <th id="T_e8fd5_level0_col3" class="col_heading level0 col3" >new_tests</th>
#       <th id="T_e8fd5_level0_col4" class="col_heading level0 col4" >day</th>
#       <th id="T_e8fd5_level0_col5" class="col_heading level0 col5" >month</th>
#       <th id="T_e8fd5_level0_col6" class="col_heading level0 col6" >weekday</th>
#       <th id="T_e8fd5_level0_col7" class="col_heading level0 col7" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8fd5_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_e8fd5_row0_col0" class="data row0 col0" >2020-08-30 00:00:00</td>
#       <td id="T_e8fd5_row0_col1" class="data row0 col1" >1444.000000</td>
#       <td id="T_e8fd5_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_e8fd5_row0_col3" class="data row0 col3" >53541.000000</td>
#       <td id="T_e8fd5_row0_col4" class="data row0 col4" >30</td>
#       <td id="T_e8fd5_row0_col5" class="data row0 col5" >8</td>
#       <td id="T_e8fd5_row0_col6" class="data row0 col6" >6</td>
#       <td id="T_e8fd5_row0_col7" class="data row0 col7" >2020</td>
#     </tr>
#     <tr>
#       <th id="T_e8fd5_level0_row1" class="row_heading level0 row1" >244</th>
#       <td id="T_e8fd5_row1_col0" class="data row1 col0" >2020-08-31 00:00:00</td>
#       <td id="T_e8fd5_row1_col1" class="data row1 col1" >1365.000000</td>
#       <td id="T_e8fd5_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_e8fd5_row1_col3" class="data row1 col3" >42583.000000</td>
#       <td id="T_e8fd5_row1_col4" class="data row1 col4" >31</td>
#       <td id="T_e8fd5_row1_col5" class="data row1 col5" >8</td>
#       <td id="T_e8fd5_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_e8fd5_row1_col7" class="data row1 col7" >2020</td>
#     </tr>
#     <tr>
#       <th id="T_e8fd5_level0_row2" class="row_heading level0 row2" >245</th>
#       <td id="T_e8fd5_row2_col0" class="data row2 col0" >2020-09-01 00:00:00</td>
#       <td id="T_e8fd5_row2_col1" class="data row2 col1" >996.000000</td>
#       <td id="T_e8fd5_row2_col2" class="data row2 col2" >6.000000</td>
#       <td id="T_e8fd5_row2_col3" class="data row2 col3" >54395.000000</td>
#       <td id="T_e8fd5_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_e8fd5_row2_col5" class="data row2 col5" >9</td>
#       <td id="T_e8fd5_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_e8fd5_row2_col7" class="data row2 col7" >2020</td>
#     </tr>
#     <tr>
#       <th id="T_e8fd5_level0_row3" class="row_heading level0 row3" >246</th>
#       <td id="T_e8fd5_row3_col0" class="data row3 col0" >2020-09-02 00:00:00</td>
#       <td id="T_e8fd5_row3_col1" class="data row3 col1" >975.000000</td>
#       <td id="T_e8fd5_row3_col2" class="data row3 col2" >8.000000</td>
#       <td id="T_e8fd5_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_e8fd5_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_e8fd5_row3_col5" class="data row3 col5" >9</td>
#       <td id="T_e8fd5_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_e8fd5_row3_col7" class="data row3 col7" >2020</td>
#     </tr>
#     <tr>
#       <th id="T_e8fd5_level0_row4" class="row_heading level0 row4" >247</th>
#       <td id="T_e8fd5_row4_col0" class="data row4 col0" >2020-09-03 00:00:00</td>
#       <td id="T_e8fd5_row4_col1" class="data row4 col1" >1326.000000</td>
#       <td id="T_e8fd5_row4_col2" class="data row4 col2" >6.000000</td>
#       <td id="T_e8fd5_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_e8fd5_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_e8fd5_row4_col5" class="data row4 col5" >9</td>
#       <td id="T_e8fd5_row4_col6" class="data row4 col6" >3</td>
#       <td id="T_e8fd5_row4_col7" class="data row4 col7" >2020</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.drop(columns=['date'], inplace=True)
new_order = ['day', 'month', 'weekday', 'year', 'new_cases', 'new_deaths', 'new_tests']
data = data[new_order]

# %%
data.tail().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_7fb1d_row0_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_7fb1d_row0_col1, #T_7fb1d_row0_col3, #T_7fb1d_row0_col5, #T_7fb1d_row1_col1, #T_7fb1d_row1_col2, #T_7fb1d_row1_col3, #T_7fb1d_row1_col6, #T_7fb1d_row2_col0, #T_7fb1d_row2_col3, #T_7fb1d_row3_col3, #T_7fb1d_row3_col4, #T_7fb1d_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7fb1d_row0_col2, #T_7fb1d_row0_col4, #T_7fb1d_row1_col0, #T_7fb1d_row2_col1, #T_7fb1d_row2_col6, #T_7fb1d_row3_col1, #T_7fb1d_row3_col5, #T_7fb1d_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7fb1d_row0_col6 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_7fb1d_row1_col4 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_7fb1d_row1_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_7fb1d_row2_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_7fb1d_row2_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7fb1d_row2_col5, #T_7fb1d_row4_col5 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_7fb1d_row3_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_7fb1d_row3_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_7fb1d_row3_col6, #T_7fb1d_row4_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7fb1d_row4_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_7fb1d_row4_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_7fb1d_row4_col4 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7fb1d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fb1d_level0_col0" class="col_heading level0 col0" >day</th>
#       <th id="T_7fb1d_level0_col1" class="col_heading level0 col1" >month</th>
#       <th id="T_7fb1d_level0_col2" class="col_heading level0 col2" >weekday</th>
#       <th id="T_7fb1d_level0_col3" class="col_heading level0 col3" >year</th>
#       <th id="T_7fb1d_level0_col4" class="col_heading level0 col4" >new_cases</th>
#       <th id="T_7fb1d_level0_col5" class="col_heading level0 col5" >new_deaths</th>
#       <th id="T_7fb1d_level0_col6" class="col_heading level0 col6" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fb1d_level0_row0" class="row_heading level0 row0" >243</th>
#       <td id="T_7fb1d_row0_col0" class="data row0 col0" >30</td>
#       <td id="T_7fb1d_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_7fb1d_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_7fb1d_row0_col3" class="data row0 col3" >2020</td>
#       <td id="T_7fb1d_row0_col4" class="data row0 col4" >1444.000000</td>
#       <td id="T_7fb1d_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_7fb1d_row0_col6" class="data row0 col6" >53541.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7fb1d_level0_row1" class="row_heading level0 row1" >244</th>
#       <td id="T_7fb1d_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_7fb1d_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_7fb1d_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_7fb1d_row1_col3" class="data row1 col3" >2020</td>
#       <td id="T_7fb1d_row1_col4" class="data row1 col4" >1365.000000</td>
#       <td id="T_7fb1d_row1_col5" class="data row1 col5" >4.000000</td>
#       <td id="T_7fb1d_row1_col6" class="data row1 col6" >42583.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7fb1d_level0_row2" class="row_heading level0 row2" >245</th>
#       <td id="T_7fb1d_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_7fb1d_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_7fb1d_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7fb1d_row2_col3" class="data row2 col3" >2020</td>
#       <td id="T_7fb1d_row2_col4" class="data row2 col4" >996.000000</td>
#       <td id="T_7fb1d_row2_col5" class="data row2 col5" >6.000000</td>
#       <td id="T_7fb1d_row2_col6" class="data row2 col6" >54395.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7fb1d_level0_row3" class="row_heading level0 row3" >246</th>
#       <td id="T_7fb1d_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_7fb1d_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_7fb1d_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_7fb1d_row3_col3" class="data row3 col3" >2020</td>
#       <td id="T_7fb1d_row3_col4" class="data row3 col4" >975.000000</td>
#       <td id="T_7fb1d_row3_col5" class="data row3 col5" >8.000000</td>
#       <td id="T_7fb1d_row3_col6" class="data row3 col6" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7fb1d_level0_row4" class="row_heading level0 row4" >247</th>
#       <td id="T_7fb1d_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_7fb1d_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_7fb1d_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_7fb1d_row4_col3" class="data row4 col3" >2020</td>
#       <td id="T_7fb1d_row4_col4" class="data row4 col4" >1326.000000</td>
#       <td id="T_7fb1d_row4_col5" class="data row4 col5" >6.000000</td>
#       <td id="T_7fb1d_row4_col6" class="data row4 col6" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
#check the overall metrics for May (i.e, the total numbers of 'new_cases', 'new_deaths', 'new_tests')
data[data['month'] == 5].select_dtypes(include=['float']).sum()
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %% [markdown]
# ### Overall metrics for May:
# - **Total numbers of 'new_cases'**: `29073 case`
# - **Total numbers of 'new_deaths'**: `5658 case`
# - **Total numbers of 'new_tests'**: `1078720 test`

# %%
#which day seems like have more cases?
data[data['month'] == 5].sort_values('new_cases', ascending=False).head(1).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_bae31_row0_col0, #T_bae31_row0_col1, #T_bae31_row0_col2, #T_bae31_row0_col3, #T_bae31_row0_col4, #T_bae31_row0_col5, #T_bae31_row0_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_bae31" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bae31_level0_col0" class="col_heading level0 col0" >day</th>
#       <th id="T_bae31_level0_col1" class="col_heading level0 col1" >month</th>
#       <th id="T_bae31_level0_col2" class="col_heading level0 col2" >weekday</th>
#       <th id="T_bae31_level0_col3" class="col_heading level0 col3" >year</th>
#       <th id="T_bae31_level0_col4" class="col_heading level0 col4" >new_cases</th>
#       <th id="T_bae31_level0_col5" class="col_heading level0 col5" >new_deaths</th>
#       <th id="T_bae31_level0_col6" class="col_heading level0 col6" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bae31_level0_row0" class="row_heading level0 row0" >123</th>
#       <td id="T_bae31_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_bae31_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_bae31_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_bae31_row0_col3" class="data row0 col3" >2020</td>
#       <td id="T_bae31_row0_col4" class="data row0 col4" >1965.000000</td>
#       <td id="T_bae31_row0_col5" class="data row0 col5" >269.000000</td>
#       <td id="T_bae31_row0_col6" class="data row0 col6" >31231.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Day `2` seems like have more cases which is `1965 case` in `2-5-2020`

# %%
#create a new dataframe with month-wise data
month_wise_data = data.groupby(['year', 'month'])[['new_cases', 'new_deaths', 'new_tests']].sum().reset_index()
month_wise_data.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_8eefb_row0_col0, #T_8eefb_row0_col2, #T_8eefb_row0_col3, #T_8eefb_row0_col4, #T_8eefb_row1_col1, #T_8eefb_row1_col2, #T_8eefb_row1_col3, #T_8eefb_row1_col4, #T_8eefb_row2_col3, #T_8eefb_row2_col4, #T_8eefb_row3_col4, #T_8eefb_row9_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8eefb_row0_col1, #T_8eefb_row1_col0, #T_8eefb_row2_col0, #T_8eefb_row3_col0, #T_8eefb_row4_col0, #T_8eefb_row4_col2, #T_8eefb_row4_col3, #T_8eefb_row5_col0, #T_8eefb_row6_col0, #T_8eefb_row7_col0, #T_8eefb_row8_col0, #T_8eefb_row8_col4, #T_8eefb_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8eefb_row2_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_8eefb_row2_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8eefb_row3_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_8eefb_row3_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_8eefb_row3_col3 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_8eefb_row4_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_8eefb_row4_col4 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_8eefb_row5_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_8eefb_row5_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_8eefb_row5_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_8eefb_row5_col4 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_8eefb_row6_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_8eefb_row6_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_8eefb_row6_col3 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_8eefb_row6_col4 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_8eefb_row7_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_8eefb_row7_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_8eefb_row7_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_8eefb_row7_col4 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_8eefb_row8_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_8eefb_row8_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_8eefb_row8_col3 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_8eefb_row9_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_8eefb_row9_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8eefb_row9_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# </style>
# <table id="T_8eefb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8eefb_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_8eefb_level0_col1" class="col_heading level0 col1" >month</th>
#       <th id="T_8eefb_level0_col2" class="col_heading level0 col2" >new_cases</th>
#       <th id="T_8eefb_level0_col3" class="col_heading level0 col3" >new_deaths</th>
#       <th id="T_8eefb_level0_col4" class="col_heading level0 col4" >new_tests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eefb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8eefb_row0_col0" class="data row0 col0" >2019</td>
#       <td id="T_8eefb_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_8eefb_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_8eefb_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_8eefb_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8eefb_row1_col0" class="data row1 col0" >2020</td>
#       <td id="T_8eefb_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_8eefb_row1_col2" class="data row1 col2" >3.000000</td>
#       <td id="T_8eefb_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_8eefb_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8eefb_row2_col0" class="data row2 col0" >2020</td>
#       <td id="T_8eefb_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_8eefb_row2_col2" class="data row2 col2" >885.000000</td>
#       <td id="T_8eefb_row2_col3" class="data row2 col3" >21.000000</td>
#       <td id="T_8eefb_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8eefb_row3_col0" class="data row3 col0" >2020</td>
#       <td id="T_8eefb_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_8eefb_row3_col2" class="data row3 col2" >100851.000000</td>
#       <td id="T_8eefb_row3_col3" class="data row3 col3" >11570.000000</td>
#       <td id="T_8eefb_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8eefb_row4_col0" class="data row4 col0" >2020</td>
#       <td id="T_8eefb_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_8eefb_row4_col2" class="data row4 col2" >101852.000000</td>
#       <td id="T_8eefb_row4_col3" class="data row4 col3" >16091.000000</td>
#       <td id="T_8eefb_row4_col4" class="data row4 col4" >419591.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8eefb_row5_col0" class="data row5 col0" >2020</td>
#       <td id="T_8eefb_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_8eefb_row5_col2" class="data row5 col2" >29073.000000</td>
#       <td id="T_8eefb_row5_col3" class="data row5 col3" >5658.000000</td>
#       <td id="T_8eefb_row5_col4" class="data row5 col4" >1078720.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8eefb_row6_col0" class="data row6 col0" >2020</td>
#       <td id="T_8eefb_row6_col1" class="data row6 col1" >6</td>
#       <td id="T_8eefb_row6_col2" class="data row6 col2" >7772.000000</td>
#       <td id="T_8eefb_row6_col3" class="data row6 col3" >1404.000000</td>
#       <td id="T_8eefb_row6_col4" class="data row6 col4" >830354.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8eefb_row7_col0" class="data row7 col0" >2020</td>
#       <td id="T_8eefb_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_8eefb_row7_col2" class="data row7 col2" >6722.000000</td>
#       <td id="T_8eefb_row7_col3" class="data row7 col3" >388.000000</td>
#       <td id="T_8eefb_row7_col4" class="data row7 col4" >797692.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8eefb_row8_col0" class="data row8 col0" >2020</td>
#       <td id="T_8eefb_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_8eefb_row8_col2" class="data row8 col2" >21060.000000</td>
#       <td id="T_8eefb_row8_col3" class="data row8 col3" >345.000000</td>
#       <td id="T_8eefb_row8_col4" class="data row8 col4" >1098704.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8eefb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8eefb_row9_col0" class="data row9 col0" >2020</td>
#       <td id="T_8eefb_row9_col1" class="data row9 col1" >9</td>
#       <td id="T_8eefb_row9_col2" class="data row9 col2" >3297.000000</td>
#       <td id="T_8eefb_row9_col3" class="data row9 col3" >20.000000</td>
#       <td id="T_8eefb_row9_col4" class="data row9 col4" >54395.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#plot a line graph showing how the number of daily cases varies over time
month_wise_data['Date'] = pd.to_datetime(month_wise_data[['year', 'month']].assign(day=1))

plt.figure(figsize=(10, 6))

plt.plot(month_wise_data['Date'], month_wise_data['new_cases'], label='New Cases', marker='o')
plt.plot(month_wise_data['Date'], month_wise_data['new_deaths'], label='New Deaths', marker='o')
plt.plot(month_wise_data['Date'], month_wise_data['new_tests'], label='New Tests', marker='o')

plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Month-Wise New Cases, Deaths, and Tests')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
month_wise_data.to_csv('covid_month_wise_data.csv', index=False)
