# %% [markdown]
# <a class="anchor" id="About_Data"></a>
# # <p style="padding:10px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500"> “American University Data” IPEDS dataset 🤓 </p>

# %% [markdown]
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExcmI5dzNiZnh1ZHFhcGw5b202NnRhZDIybnd3c2x2N2szbng5Nzh3dCZlcD12MV9naWZzX3NlYXJjaCZjdD1n/BiOSVU5K9rXR6/200.webp" width="150%" height="100%">

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#296EAA">[Introduction](#intro)</span>
#
# - <span style="color:#296EAA">[1.1 About This Project](#goals)</span>
# - <span style="color:#296EAA">[1.2 Data Overview](#dataoverview)</span>
#
# ### <span style="color:#296EAA">[General Questions](#generalquestions)</span>
#
# ### <span style="color:#296EAA">[Import the Necessary Libraries](#libraries)</span>
#
#
# ### <span style="color:#296EAA">[Reading the Data](#datareading)</span>
#
# ### <span style="color:#296EAA">[EDA](#eda)</span>
#
# ### <span style="color:#296EAA">[Conclusion ](#end)</span>

# %% [markdown]
# ---

# %% [markdown]
# <a class="anchor" id="intro"></a>
# # <p style="padding:10px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Introduction 🎓  </p>

# %% [markdown]
# - Most American institutions (that are not necessarily the top 10-20) that provide undergraduate education face a challenge i.e.
#   - what kind of students they will make an offer for admission so that they can maintain a good performance in terms of number of students completing their courses in time.
#   - They also need to predict how the current batch of intake will perform.
#
# - The universities cannot relax the entry criteria too much as that way the quality of education that they provide gets diluted. At the other hand, they have to make offers to the candidates who are not only having appropriate profile but are also most likely to accept the offers.<br>
#
#    ---
#
# - On the other side, the students have a challenge deciding which colleges they should apply i.e.
#    - the colleges that provide best performance at a minimal cost given their own profiles. <br>
# The student profile is determined by not only the performance in examination such as SAT and ACT, but also other data points such as their ethnicity, immigration status, gender etc.

# %% [markdown]
# ---

# %% [markdown]
# <a id="goals"></a>
# ### <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:200"> About This Project 📜</p>

# %% [markdown]
# The aim of this Task is to find out :
# - which are the most relevant features that students consider to choose their preferred American university. <br>
# - Some of the essential questions
# for developing this project are related to the number of applications,
# admissions, and enrollments, cost of tuition and fees, cost of living on
# campus, types of degrees offered, and features of the states where universities
# are located (population and GDP).

# %% [markdown]
# ---

# %% [markdown]
# <a id="dataoverview"></a>
# ### <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:200"> Data Overview 🌟</p>

# %% [markdown]
# The  ["IPEDS dataset"](https://www.kaggle.com/datasets/sumithbhongale/american-university-data-ipeds-dataset) It is called “American University Data”.<br>
#  This is a smaller version of dataset available at :
# https://nces.ed.gov/ipeds/Home/UseTheData.. <br>
#
#  The dataset consists of `1,534 `records and `153` columns. Here is an overview of the dataset columns:

# %% [markdown]
# ---

# %% [markdown]
# <a id="generalquestions"></a>
# # <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500"> General Questions 🙋 </p>

# %% [markdown]
# 1.
# Do
# universities with a high number of applications are the preferred ones by students?
# in other words, could the number of applications tell us that a university is
# one of the most preferred by students?
#
#
# 2.
# Do
# students prefer universities that have a high rate of admission?, in other
# words, do students prefer a university where it is easier for them to be
# admitted?.
#
#
# 3.
# Do
# students prefer public or private universities?
#
#
# 4.
# Do
# students prefer universities with low tuition and fees?
#
#
# 5.
# Do
# students prefer a university for its low on-campus cost of living?
#
#
# 6.
# Do
# students prefer universities from highly populated states?
#
#
# 7.
# Do
# students prefer a university because it belongs to a state with a high GDP per
# capita?
#
#
# 8.
# Do
# students prefer a university based on the possibility of a higher, additional
# academic degree in the same university?

# %% [markdown]
# ---

# %% [markdown]
# <a id="dataoverview"></a>
# # <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500"> Import the Necessary Libraries 📚</p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ---

# %% [markdown]
# <a id="datareading"></a>
# # <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500"> Reading the data 📖</p>

# %%
data = pd.read_excel('/content/IPEDS_data.xlsx')
data.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ---

# %% [markdown]
# <a id="eda"></a>
# # <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500"> EDA 📊</p>

# %%
Need_columns = [
'Name' , 'Highest degree offered' , 'Applicants total' , 'Admissions total' , 'Enrolled total' , 'Percent admitted - total' , 'Admissions yield - total',
'Tuition and fees, 2013-14' , 'Total price for in-state students living on campus 2013-14' , 'Total price for out-of-state students living on campus 2013-14',
'State abbreviation' , 'Control of institution'
]

# %%
New_data = data[Need_columns]
New_data.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_0179f_row0_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_0179f_row0_col3, #T_0179f_row0_col5, #T_0179f_row1_col4, #T_0179f_row3_col6, #T_0179f_row3_col7, #T_0179f_row3_col8, #T_0179f_row3_col9, #T_0179f_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0179f_row0_col4 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_0179f_row0_col6, #T_0179f_row2_col7, #T_0179f_row3_col2, #T_0179f_row3_col3, #T_0179f_row3_col4, #T_0179f_row4_col5, #T_0179f_row4_col8, #T_0179f_row4_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0179f_row0_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_0179f_row0_col8 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_0179f_row0_col9 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_0179f_row1_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_0179f_row1_col3 {
#   background-color: #0d57a1;
# ...

# %%
New_data.shape
# Out:
# (1534, 12)

# %%
New_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Data columns (total 12 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Name                                                            1534 non-null   object
#  1   Highest degree offered                                          1534 non-null   object
#  2   Applicants total                                                1377 non-null   float64
#  3   Admissions total                                                1377 non-null   float64
#  4   Enrolled total                                                  1377 non-null   float64
#  5   Percent admitted - total                                        1376 non-null   float64
#  6   Admissions yield - total                                        1376 non-null   float64
# ...

# %%
New_data.describe().T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_84ff4_row0_col0, #T_84ff4_row1_col0, #T_84ff4_row2_col0, #T_84ff4_row2_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_84ff4_row0_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_84ff4_row0_col2 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_84ff4_row0_col3, #T_84ff4_row1_col3, #T_84ff4_row2_col3, #T_84ff4_row3_col0, #T_84ff4_row3_col1, #T_84ff4_row3_col2, #T_84ff4_row3_col3, #T_84ff4_row3_col4, #T_84ff4_row3_col5, #T_84ff4_row3_col6, #T_84ff4_row3_col7, #T_84ff4_row4_col0, #T_84ff4_row4_col1, #T_84ff4_row4_col2, #T_84ff4_row4_col3, #T_84ff4_row4_col4, #T_84ff4_row4_col5, #T_84ff4_row4_col6, #T_84ff4_row4_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_84ff4_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_84ff4_row0_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_84ff4_row0_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# ...

# %%
New_data.describe(include="object").T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c58cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c58cb_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_c58cb_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_c58cb_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_c58cb_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c58cb_level0_row0" class="row_heading level0 row0" >Name</th>
#       <td id="T_c58cb_row0_col0" class="data row0 col0" >1534</td>
#       <td id="T_c58cb_row0_col1" class="data row0 col1" >1517</td>
#       <td id="T_c58cb_row0_col2" class="data row0 col2" >Westminster College</td>
#       <td id="T_c58cb_row0_col3" class="data row0 col3" >3</td>
#     </tr>
#     <tr>
# ...

# %%
# Null values
New_data.isnull().sum()
# Out:
# Name                                                                0
# Highest degree offered                                              0
# Applicants total                                                  157
# Admissions total                                                  157
# Enrolled total                                                    157
# Percent admitted - total                                          158
# Admissions yield - total                                          158
# Tuition and fees, 2013-14                                          37
# Total price for in-state students living on campus 2013-14        134
# Total price for out-of-state students living on campus 2013-14    134
# State abbreviation                                                  0
# Control of institution                                              0
# dtype: int64

# %%
New_data.isna().sum()/data.shape[0]*100
# Out:
# Name                                                               0.000000
# Highest degree offered                                             0.000000
# Applicants total                                                  10.234681
# Admissions total                                                  10.234681
# Enrolled total                                                    10.234681
# Percent admitted - total                                          10.299870
# Admissions yield - total                                          10.299870
# Tuition and fees, 2013-14                                          2.411995
# Total price for in-state students living on campus 2013-14         8.735332
# Total price for out-of-state students living on campus 2013-14     8.735332
# State abbreviation                                                 0.000000
# Control of institution                                             0.000000
# dtype: float64

# %%
New_data.duplicated().sum()
# Out:
# 0

# %%
New_data.nunique()
# Out:
# Name                                                              1517
# Highest degree offered                                               6
# Applicants total                                                  1298
# Admissions total                                                  1236
# Enrolled total                                                     963
# Percent admitted - total                                            95
# Admissions yield - total                                            82
# Tuition and fees, 2013-14                                         1384
# Total price for in-state students living on campus 2013-14        1350
# Total price for out-of-state students living on campus 2013-14    1343
# State abbreviation                                                  51
# Control of institution                                               2
# dtype: int64

# %%
for col in New_data.columns:
    print(f"{col}: {New_data[col].value_counts()} \n-------------------------------\n")
# Out:
# Name: Name
# Westminster College                              3
# Union College                                    3
# Columbia College                                 2
# University of St Thomas                          2
# Bethel University                                2
#                                                 ..
# University of Maryland-College Park              1
# University of Maryland-Baltimore County          1
# University of Maryland-University College        1
# Loyola University Maryland                       1
# Polytechnic University of Puerto Rico-Orlando    1
# Name: count, Length: 1517, dtype: int64
# -------------------------------
#
# Highest degree offered: Highest degree offered
# Master's degree                                                     587
# Doctor's degree - research/scholarship and professional practice    311
# Bachelor's degree                                                   282
# ...

# %% [markdown]
# ## Initial Data Assessment `New Needed Columns` 📋
# - **Number of Samples**: `1534`
# - **Number of Columns**: `12`
# - **Missing Values**:`175` Missing values in the "Applicants total",
# "Admissions total",
# "Enrolled total"	,
# "Percent admitted" ,
# "Admissions yield - total" columns , about `10%` of data.
# - **Data Types**:
#   - Object (Categorical): 4 column .
#   - And the other `8` columns float
#
# - **Data Distribution**:
#   - Columns dtypes are correct.
#   - Numeric features have varying ranges and distributions.
#
#   - There are no duplicate rows in the DataFrame

# %% [markdown]
# ---

# %% [markdown]
#  ### Univariate Data Visualizations :

# %% [markdown]
# - Numerical columns:

# %%
for col in New_data.select_dtypes('number').columns:
    sns.displot(New_data[col])

# %% [markdown]
# - "Applications Total" :
#   - `Right skewness`.
#   - The majority of data between `0` : `10,000`.
#
# - "Admissions total" :
#  - `Right skewness`.
#  - The majority of data between `0` : `40,000`.
# - "Enrolled total" :
#    - `Right skewness`.
#    - The majority of data between `0` : `10,000`.
# -	"Percent admitted total" :
#    - `Left skewness`.
#    - The majority of data between `60%` : `80%`.
# - "Admissions yield total" :
#     - `Right skewness`.
#     - The majority of data between `20%` : `40%`.
# - "Tuition and fees, 2013-14" :
#    - The majority of data between `5,000` : `10,000`.
# - "Total price for in-state students living on campus 2013-14" :
#   - The majority of data around `20,000`.
# - "Total price for out-of-state students living on campus 2013-14" :
#   - `No skewness`
#   - The majority of data between `30,000` : `40,000`.

# %% [markdown]
# ---

# %% [markdown]
# - Categorical columns :

# %%
colors = ['#08306b', '#08519c', '#2171b5', '#6baed6', '#c6dbef']

plt.figure(figsize=(10, 6))
sns.countplot(New_data , x='Highest degree offered' , hue='Highest degree offered', palette=colors)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()

# %%
sns.countplot(New_data , x='Control of institution' , hue='Control of institution', palette=[colors[0], colors[4]])
plt.xticks(rotation=30, ha='right')
plt.tight_layout()

# %% [markdown]
# - Most of the universities offer `Master's degree` as the highest degree.
# - Most of the universities are `Private`.

# %% [markdown]
# ---

# %% [markdown]
# - Heatmap :

# %%
sns.heatmap(New_data.select_dtypes('number').corr() , annot=True, cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# - Admission yield, percent admitted and enrolled total is inverse propotional with the fees and total price which is true of course <br>
# - Enrolled total there is no linear correlation with out-state total price which need more investigation <br>
# - it seems that out-state see to have tendency to pay more<br>
# - it seems also that the more applications the less acceptance of them

# %% [markdown]
# ---

# %%
New_data.columns
# Out:
# Index(['Name', 'Highest degree offered', 'Applicants total',
#        'Admissions total', 'Enrolled total', 'Percent admitted - total',
#        'Admissions yield - total', 'Tuition and fees, 2013-14',
#        'Total price for in-state students living on campus 2013-14',
#        'Total price for out-of-state students living on campus 2013-14',
#        'State abbreviation', 'Control of institution'],
#       dtype='object')

# %% [markdown]
# ### 1. Do universities with a `high number of applications` are the preferred ones by students? in other words, could the number of applications tell us that a university is one of the most preferred by students?

# %%
sns.scatterplot(data=New_data , x='Applicants total' , y='Admissions yield - total' )
# Out:
# <Axes: xlabel='Applicants total', ylabel='Admissions yield - total'>

# %% [markdown]
# - it seems that univerisites with low application number has more admmitions.
# - but we cannot decide from this only.
# ---

# %% [markdown]
# ### 2. Do students prefer universities that have a `high rate of admission`?, in other words, do students prefer a university where it is easier for them to be admitted?

# %%
sns.scatterplot(data=New_data , x='Percent admitted - total' , y='Applicants total' )
# Out:
# <Axes: xlabel='Percent admitted - total', ylabel='Applicants total'>

# %% [markdown]
# - it seems that students don't prefer universities that have a high rate of admission.
# ---

# %% [markdown]
# ### 3. Do students prefer `public or private` universities?

# %%
sns.barplot(data=New_data , x='Control of institution' , y='Applicants total' ,  palette=[colors[0], colors[4]])
# Out:
# <Axes: xlabel='Control of institution', ylabel='Applicants total'>

# %% [markdown]
# - it seems that students prefer public universities in application stage.

# %%
sns.barplot(data=New_data , x='Control of institution' , y='Tuition and fees, 2013-14' ,  palette=[colors[0], colors[4]])
# Out:
# <Axes: xlabel='Control of institution', ylabel='Tuition and fees, 2013-14'>

# %% [markdown]
# - it seems that students prefer public universities in Enrollment stage also.
# - it may be relevant to the fee :)

# %%
sns.barplot(data=New_data , x='Control of institution' , y='Enrolled total' ,  palette=[colors[0], colors[4]])
# Out:
# <Axes: xlabel='Control of institution', ylabel='Enrolled total'>

# %% [markdown]
# - As we can see public have low fees so it is meaningful.
# ---

# %% [markdown]
# ### 4. Do students prefer universities with `low tuition and fees`?

# %%
sns.scatterplot(data=New_data , x='Tuition and fees, 2013-14' , y='Applicants total' )
# Out:
# <Axes: xlabel='Tuition and fees, 2013-14', ylabel='Applicants total'>

# %% [markdown]
# - in applying for the university it doesnot matter.

# %%
sns.scatterplot(data=New_data , x='Tuition and fees, 2013-14' , y='Admissions yield - total' )
# Out:
# <Axes: xlabel='Tuition and fees, 2013-14', ylabel='Admissions yield - total'>

# %% [markdown]
# - when enrolling students tends to enroll in universities with low tutions
# ---

# %% [markdown]
# ### 5. Do students prefer a university for its `low on-campus cost of living`?

# %%
sns.scatterplot(data=New_data , x='Total price for in-state students living on campus 2013-14' , y='Applicants total' )
# Out:
# <Axes: xlabel='Total price for in-state students living on campus 2013-14', ylabel='Applicants total'>

# %%
sns.scatterplot(data=New_data , x='Total price for in-state students living on campus 2013-14' , y='Admissions yield - total' )
# Out:
# <Axes: xlabel='Total price for in-state students living on campus 2013-14', ylabel='Admissions yield - total'>

# %%
sns.scatterplot(data=New_data , x='Total price for out-of-state students living on campus 2013-14' , y='Applicants total' )
# Out:
# <Axes: xlabel='Total price for out-of-state students living on campus 2013-14', ylabel='Applicants total'>

# %%
sns.scatterplot(data=New_data , x='Total price for out-of-state students living on campus 2013-14' , y='Admissions yield - total' )
# Out:
# <Axes: xlabel='Total price for out-of-state students living on campus 2013-14', ylabel='Admissions yield - total'>

# %% [markdown]
# - in applying for the university it doesnot matter
# but when enrolling students tends to enroll in universities with low total price.
# ---

# %% [markdown]
# ### 6. Do students prefer universities from highly `populated states`?

# %%
New_data['State abbreviation'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
high_populated = ['California', 'Florida', 'Georgia', 'Illinois', 'Michigan','New York', 'North Carolina', 'Ohio', 'Pennsylvania', 'Texas']

# %%
New_data['high_populated'] = New_data['State abbreviation'].apply(lambda x: "High" if x in high_populated else "Low")

# %%
New_data.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_9259a_row0_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_9259a_row0_col3, #T_9259a_row0_col5, #T_9259a_row1_col4, #T_9259a_row3_col6, #T_9259a_row3_col7, #T_9259a_row3_col8, #T_9259a_row3_col9, #T_9259a_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9259a_row0_col4 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_9259a_row0_col6, #T_9259a_row2_col7, #T_9259a_row3_col2, #T_9259a_row3_col3, #T_9259a_row3_col4, #T_9259a_row4_col5, #T_9259a_row4_col8, #T_9259a_row4_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9259a_row0_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_9259a_row0_col8 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_9259a_row0_col9 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_9259a_row1_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_9259a_row1_col3 {
#   background-color: #0d57a1;
# ...

# %%
sns.barplot(data=New_data , x='high_populated' , y='Applicants total' ,  palette=[colors[0], colors[4]])
# Out:
# <Axes: xlabel='high_populated', ylabel='Applicants total'>

# %% [markdown]
# - it seems that students prefer High populated universities in application stage.

# %%
sns.barplot(data=New_data , x='high_populated' , y='Admissions yield - total' ,  palette=[colors[0], colors[4]])
# Out:
# <Axes: xlabel='high_populated', ylabel='Admissions yield - total'>

# %% [markdown]
# - but they tend to prefer Low populated in Enrollment stage.
# ---

# %% [markdown]
# ### 7. Do students prefer a university because it belongs to a `state with a high GDP per capita`?

# %%
high_GDP = ['Massachusetts', 'Connecticut', 'New York', 'California', 'New Jersey','Alaska','Texas']

# %%
New_data['high_GDP'] = New_data['State abbreviation'].apply(lambda x: "High" if x in high_GDP else "Low")

# %%
New_data.head().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_f924b_row0_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_f924b_row0_col3, #T_f924b_row0_col5, #T_f924b_row1_col4, #T_f924b_row3_col6, #T_f924b_row3_col7, #T_f924b_row3_col8, #T_f924b_row3_col9, #T_f924b_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f924b_row0_col4 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_f924b_row0_col6, #T_f924b_row2_col7, #T_f924b_row3_col2, #T_f924b_row3_col3, #T_f924b_row3_col4, #T_f924b_row4_col5, #T_f924b_row4_col8, #T_f924b_row4_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f924b_row0_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_f924b_row0_col8 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_f924b_row0_col9 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_f924b_row1_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_f924b_row1_col3 {
#   background-color: #0d57a1;
# ...

# %%
sns.barplot(data=New_data , x='high_GDP' , y='Applicants total' ,  palette=[colors[0], colors[4]])
# Out:
# <Axes: xlabel='high_GDP', ylabel='Applicants total'>

# %% [markdown]
# - it seems that students prefer High GDP universities in application stage.

# %%
sns.barplot(data=New_data , x='high_GDP' , y='Admissions yield - total' ,  palette=[colors[0], colors[4]])
# Out:
# <Axes: xlabel='high_GDP', ylabel='Admissions yield - total'>

# %% [markdown]
# - but students prefer Low GDP universities in enrollment stage.
# ---

# %% [markdown]
# ### 8. Do students prefer a university based on the possibility of a `higher, additional academic degree` in the same university?

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=New_data , x='Highest degree offered' , y='Applicants total' ,  palette=[colors[0],colors[1],colors[2],colors[3],colors[4]])
plt.xticks(rotation=30, ha='right')
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=New_data , x='Highest degree offered' , y='Admissions yield - total' , palette=[colors[0],colors[1],colors[2],colors[3],colors[4]])
plt.xticks(rotation=30, ha='right')
plt.tight_layout()

# %% [markdown]
# - it seems that it doesnot matter in enrollment, but they prefer higher degree while application stage.
# ---

# %% [markdown]
# <a id="end"></a>
# # <p style="padding:5px;background-color:#7EC0EE;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 50px 15px;overflow:hidden;font-weight:500"> Conclusion 🎗️</p>

# %% [markdown]
# - students prefers public universites.
# - students prefers low tutions in enrolling.
# - students prefers high gdp with high population in applying.
# - students prefer universities with higher or additional degree.
